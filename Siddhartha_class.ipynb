# %%
import numpy as np
import pandas as pd

# %%
with open("siddhartha.txt", "r") as file:
    raw = file.read()

# %%
chapters = raw.split("CHAPTER")[1:]

# %%
len(chapters)
# Out:
# 12

# %%
txt = chapters[0]

# %%
# Get the chapter title, number, text
number_title = txt.split("\n")[0]
number = number_title.split(":")[0][1:]
title = number_title.split(":")[1].strip()
number, title
# Out:
# ('1', 'THE SON OF THE BRAHMAN')

# %% [markdown]
# chapter | name | line_no | word |

# %%
lines = txt.split("\n")
df_txt = pd.DataFrame({"line_txt" : lines})

# %%
df_txt.head()
df_txt["title"] = title
df_txt["chapter"] = number
df_txt["line_count"] = df_txt.index + 1

# %%
df_txt.head()
# Out:
#                                             line_txt                   title  \
# 0                         -1: THE SON OF THE BRAHMAN  THE SON OF THE BRAHMAN
# 1                                                     THE SON OF THE BRAHMAN
# 2  In the shade of the house, in the sunshine of ...  THE SON OF THE BRAHMAN
# 3  boats, in the shade of the Sal-wood forest, in...  THE SON OF THE BRAHMAN
# 4  is where Siddhartha grew up, the handsome son ...  THE SON OF THE BRAHMAN
#
#   chapter  line_count
# 0       1           1
# 1       1           2
# 2       1           3
# 3       1           4
# 4       1           5

# %%
for txt in chapters:
    number_title = txt.split("\n")[0]
    number = number_title.split(":")[0][1:]
    title = number_title.split(":")[1].strip()
    lines = txt.split("\n")
    df_txt = pd.
# Out:
#   File "<ipython-input-65-6749c1d55185>", line 6
#     df_txt = pd.
#                 ^
# SyntaxError: invalid syntax
